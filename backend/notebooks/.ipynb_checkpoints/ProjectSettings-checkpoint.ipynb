# %% [markdown]
# # Create Jupyter encrypted password

# %%
from notebook.auth import passwd
passwd()
# Out:
# Enter password: ········
# Verify password: ········
# 'sha1:f9907762807c:cf897faf0adf8bf2159ce6b3fbb4063d90eadb2b'
