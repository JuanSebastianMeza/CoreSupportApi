# %%
import os
import requests

os.environ['NO_PROXY'] = '127.0.0.1'
proxies = {
  'http': 'http://e10206:rick.005@10.162.64.36:8080',
  'https': 'http://e10206:rick.005@10.162.64.36:8080',
}

# base = 'http://dev1.tmve.local/api-token-auth/'
base = 'http://127.0.0.1:8000/'
# base = 'https://asilinks.com/api/dev/resources/know_fields/tree_format/'

for user in ['E10206']:
    auth_response = requests.post('{}api-token-auth/'.format(base), 
        data={'username': user, 'password': 'rick.002'}).json()
    
    globals()[user] = requests.Session()
    globals()[user].headers.update({'authorization': 'JWT ' + auth_response['token']})

# %%
auth_response
# Out:
# {'token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....P7a7Avtk3SVQ3ZlOL2O0UXZ80FKjiWULImRaaeQxApk'}

# %%
E10206.post('{}change-password/'.format(base),
            data={'oldPassword': 'rick.002', 'newPassword': 'rick.001', 'userId': 1,}).json()
# Out:
# {'status': False}

# %%
E10206.post('{}change-password/'.format(base),
            data={'oldPassword': 'rick.002', 'newPassword': 'rick.001', 'userId': 1,}).json()
# Out:
# {'status': True}

# %%
data={'oldPassword': {'username':'rick.002'}, 'newPassword': 'rick.001', 'userId': 1,}
data['oldPassword'].get('username')
# Out:
# 'rick.002'

# %%
jwt = {'status': 400}
jwt['status']
# Out:
# 400

# %%
jwt['status'] = {'ojo': 'tigre'}
jwt
# Out:
# {'status': {'ojo': 'tigre'}}

# %%
jwt['perro'] = 2
jwt
# Out:
# {'status': {'ojo': 'tigre'}, 'perro': 2}

# %%
from authentication.models import Profile
from django.contrib.auth.models import User

Profile.objects.get(user=User.objects.get(username='E10206')).
# Out:
# <Profile: Profile object (1)>

# %%
int(1.0)
# Out:
# 1
