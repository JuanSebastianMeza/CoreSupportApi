# %% [markdown]
# # Create Jupyter encrypted password

# %%
from notebook.auth import passwd
passwd()
# Out:
# Enter password: ········
# Verify password: ········
# 'sha1:29a62bd8ccb0:c575f955f7892be90b5e05514525c60f5dc5135a'
