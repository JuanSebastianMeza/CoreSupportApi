# %%
from django.contrib.auth.models import User

# Get users
User.objects.get(username='E10206')
# Out:
# <User: E10206>

# %% [markdown]
# # Create new user

# %%
from django.contrib.auth.models import User

# New user data
password='123456$'
is_superuser=True
username='E10355'
first_name='Yhonsky'
last_name='Pereira'
email='yhonsky.pereira@telefonica.com'
is_staff=True
position=1
department=1

# Create user
new_user = User(username=username, first_name=first_name, last_name=last_name, email=email)
new_user.is_superuser = is_superuser
new_user.is_staff = is_staff
new_user.set_password(password)
new_user.save()
new_user
# Out:
# <User: E10355>

# %% [markdown]
# # Create new position

# %%
from authentication.models import Position

# New position name
position=''

# Create new position
new_position = Position(name=position)
new_position.save()
new_position
# Out:
# <QuerySet []>

# %% [markdown]
# # Create new department

# %%
from authentication.models import Department

# New department name
department=''

# Create new department
new_department = Department(name=department)
new_department.save()
new_department
# Out:
# <QuerySet []>

# %% [markdown]
# # Create a new profile

# %%
from authentication.models import Profile

# Profile data
user = 
position = 
department = 

# Create new Profile
new_profile = Profile(user=user, position=position, department=department)
new_profile.save()
new_profile
